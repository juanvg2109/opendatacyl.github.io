# %% [markdown]
# ### Ejemplo de índice web

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Meter imágenes en el markdown. Crear celda markdown y hacer copiar-pegar a la celda desde una imagen (o arrastrarla)

# %% [markdown]
# Este es un ejemplo de texto que da entrada a una lista genérica de enlaces:
# - [Link a enlace1][link1]
# - [Link a enlace2](./P_test_web.html)
# - Elemento 3
# [link1]: https://markdown.es/sintaxis-markdown/

# %% [markdown]
# Más ejemplos: https://markdown.es/sintaxis-markdown/

# %%
#!jupyter nbconvert --no-input --to html index.ipynb
# Out:
# [NbConvertApp] Converting notebook index.ipynb to html
# [NbConvertApp] Writing 699471 bytes to index.html
